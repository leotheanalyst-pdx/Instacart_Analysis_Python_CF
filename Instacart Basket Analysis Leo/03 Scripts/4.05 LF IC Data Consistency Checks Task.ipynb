# %% [markdown]
# # Exercise 4.5 preparation

# %% [markdown]
# ## Import libraries

# %%
# import libraries

import pandas as pd
import numpy as np
import os

# %%
# create path

path = r'C:\Users\leobs\OneDrive\Data Program\Achievement 4_Instacart\Instacart Basket Analysis'

# %% [markdown]
# ## Load data

# %%
# Load product data set

df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
# check headings for accurate load

df_prods.head()

#appears accurate but need to remove columns
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# remove unnamed

df_prods = df_prods.drop(columns = ['Unnamed: 0'])

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# load orders data set from wrangled data

df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'), index_col = False)

# %%
# quick check headings for accurate load

df_ords.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             1           1   2398795        1             2
# 2             2           2    473747        1             3
# 3             3           3   2254736        1             4
# 4             4           4    431534        1             5
#
#    order_day_of_week  order_hour_of_day  days_since_last_order
# 0                  2                  8                    NaN
# 1                  3                  7                   15.0
# 2                  3                 12                   21.0
# 3                  4                  7                   29.0
# 4                  4                 15                   28.0

# %%
# remove columns

df_ords = df_ords.drop(columns = ['Unnamed: 0.1', 'Unnamed: 0'])

# %% [markdown]
# ## Data consistency checks

# %%
# load df.describe for orders df

df_ords.describe()
# Out:
#            order_id       user_id  order_number  order_day_of_week  \
# count  3.421083e+06  3.421083e+06  3.421083e+06       3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01       2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01       2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00       0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00       1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01       3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01       5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02       6.000000e+00
#
#        order_hour_of_day  days_since_last_order
# count       3.421083e+06           3.214874e+06
# mean        1.345202e+01           1.111484e+01
# std         4.226088e+00           9.206737e+00
# min         0.000000e+00           0.000000e+00
# 25%         1.000000e+01           4.000000e+00
# 50%         1.300000e+01           7.000000e+00
# ...

# %% [markdown]
# ## Mixed-type data

# %%
# Create a datafram

df_test = pd.DataFrame()

# %%
# Create a mixed data type column

df_test['mix'] = ['a', 'b', 1, True]

# %%
df_test.head()
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %%
#Check for mixed types

for col in df_test.columns.tolist(): 
    weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1) 
    if len (df_test[weird]) > 0: 
        print (col)
# Out:
# mix

# %%
# Change data type from mix to string

df_test['mix'] = df_test['mix'].astype('str')

# %%
# Check for succesful data type change

df_test.dtypes
# Out:
# mix    object
# dtype: object

# %% [markdown]
# ## Missing values

# %%
# Assign function to df_prods dataframe to find number of missing observations

df_prods.isnull().sum()

#Only product_name column has missing values, and 16 observations are missing
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
# Create new dataframe only containing the 16 observations with missing values

df_nan = df_prods[df_prods['product_name'].isnull() == True]

# %%
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
# Create new dataframe only containing rows without missing data from df_prods

df_prods_clean = df_prods[df_prods['product_name'].isnull () == False]

# %%
# Check for removal of missing rows

df_prods_clean.shape

# Confirmed as properly removed, exactly 16 rows less
# Out:
# (49677, 5)

# %% [markdown]
# ## Check for full duplicates

# %%
# identify all full duplicates in cleaned products df

df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
# list of full duplicates 

df_dups

# there are 5 full duplicates in the df_prods_clean data frame
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %% [markdown]
# ## Remove full duplicates as a new dataframe

# %%
# create new df that drops all duplicates

df_prods_clean_no_dups = df_prods_clean.drop_duplicates()

# %%
# check shack in df_prods_clean_no_dups to make sure only duplicates dropped, total rows minus duplicated rows

df_prods_clean_no_dups.shape

#accurate number dropped, 5 fewer
# Out:
# (49672, 5)

# %%
# Export cleaned and no duplicates products dataframe as new file

df_prods_clean_no_dups.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'df_prods_checked.csv'))

# %% [markdown]
# # Exercise 4.5 task: consistency checks

# %% [markdown]
# ## 1 Finalize data checks for df_prods_checked

# %% [markdown]
# Note: already checked for missing values (16) and full duplicates (5) and removed them from df_prods from exericse work.
#
# Now will import updated data file 'df_prods_checked' to complete remaining data consistency checks

# %%
# Load products data set

df_prods_checked = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'df_prods_checked.csv'), index_col = False)

# %%
df_prods_checked.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# remove unnamed columns

df_prods_checked = df_prods_checked.drop(columns = ['Unnamed: 0'])

# %%
df_prods_checked.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# descriptive stats for df_prods_checked

df_prods_checked.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49672.000000  49672.000000   49672.000000  49672.000000
# mean   24850.349775     67.762442      11.728942      9.993282
# std    14340.705287     38.315784       5.850779    453.615536
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12432.750000     35.000000       7.000000      4.100000
# 50%    24850.500000     69.000000      13.000000      7.100000
# 75%    37268.250000    100.000000      17.000000     11.100000
# max    49688.000000    134.000000      21.000000  99999.000000

# %% [markdown]
# All columns have the same count, showing consistency
# The product_id max does not match the count of product_ids, but the difference likely due to removal of missing values and duplicates.
# All columns have a minimum value of 1, consistent
# Min, max, and quartiles of product_id, aisle_id, and department_id appear consistent
#
# Further investigation Max value of 99999.00 for prices seems too high, especially given quartile values

# %% [markdown]
# ## Address inconsistencies with 'price' outliers

# %%
# Investigate price max of 99999.00 given high price for a grocery product, starting with price point 50

df_prods_checked.loc[df_prods_checked['prices'] > 50.00]

# returns results of two key outliers, product ids 21553 and 33664
# Out:
#        product_id                      product_name  aisle_id  department_id  \
# 21538       21553  Lowfat 2% Milkfat Cottage Cheese       108             16
# 33649       33664             2 % Reduced Fat  Milk        84             16
#
#         prices
# 21538  14900.0
# 33649  99999.0

# %%
# Check for all milk products in diary to replace milk price for product_id 3364
df_milk_prods = df_prods_checked.loc[(df_prods_checked['product_name'].str.contains ('milk')) & (df_prods_checked['department_id'] ==16)]

# %%
# new df of all products containing 'milk' and in department 16, diary
df_milk_prods
# Out:
#        product_id                                       product_name  \
# 133           137                               Very Vanilla Soymilk
# 204           208  Vanilla Almond Cashew Almondmilk Cashewmilk Blend
# 324           329                       Organic Whole Grassmilk Milk
# 1396         1402                              Plain Soymilk Creamer
# 2464         2473                                       West Soymilk
# ...           ...                                                ...
# 45986       46003                        Low Fat Cultured Buttermilk
# 46658       46675                        Vanilla Cultured Almondmilk
# 47746       47763                        Pure Unsweetened Cashewmilk
# 48628       48645                            Unsweetened Coconutmilk
# 49321       49338                          Original Enriched Soymilk
#
#        aisle_id  department_id  prices
# 133          91             16     1.2
# 204          91             16     3.2
# ...

# %%
df_milk_prods['prices'].median()

#will use median value to replace milk price
# Out:
# 7.2

# %%
df_milk_prods['prices'].mean()
# Out:
# 7.517857142857144

# %%
# Create new df for cottage cheese products to find median price for replacement

df_cottage_c_prods = df_prods_checked.loc[df_prods_checked['product_name'].str.contains ('Cottage')]

# %%
df_cottage_c_prods
# Out:
#        product_id                                       product_name  \
# 191           195  Grade A Pasteurized 2% Milkfat Lowfat Cottage ...
# 1497         1503                             Low Fat Cottage Cheese
# 2568         2577       2% Milk Fat Creamy Small Curd Cottage Cheese
# 2933         2943  Low Fat, Small Curd 1% Milkfat No Salt Added C...
# 3775         3788             Strawberry 100 Calorie Cottage Doubles
# ...           ...                                                ...
# 46770       46787                            Fat Free Cottage Cheese
# 47088       47105                   Organic Pineapple Cottage Cheese
# 47090       47107  4% Milkfat Small Curd Grade A Pasteurized Cott...
# 47421       47438                          Pineapple Cottage Doubles
# 48242       48259         Non Fat Grade A Pasteurized Cottage Cheese
#
#        aisle_id  department_id  prices
# 191         108             16     3.3
# 1497        108             16     6.7
# ...

# %%
# median price of cottage cheese products to update product_id '21553' price value

df_cottage_c_prods['prices'].median()
# Out:
# 6.85

# %%
# update inaccurate outliers, replace product_id '33664' price from 99999.0000 to 7.2 and replace product_id '21553' from price of 14900.0 to 6.85

df_prods_checked = df_prods_checked.replace ({'prices':{99999.0: 7.2, 14900.0: 6.85}})

# %%
# check if changes executed properly for Cottage Cheese

df_prods_checked[df_prods_checked['product_id']==21553]

#yes
# Out:
#        product_id                      product_name  aisle_id  department_id  \
# 21538       21553  Lowfat 2% Milkfat Cottage Cheese       108             16
#
#        prices
# 21538    6.85

# %%
# check if changes executed properly for 2 % Milk

df_prods_checked[df_prods_checked['product_id']==33664]

#yes
# Out:
#        product_id           product_name  aisle_id  department_id  prices
# 33649       33664  2 % Reduced Fat  Milk        84             16     7.2

# %%
# rerun descriptive stats to check for consistencies with updated outlier values

df_prods_checked.describe()

# consistency check shows accurate results
# Out:
#          product_id      aisle_id  department_id        prices
# count  49672.000000  49672.000000   49672.000000  49672.000000
# mean   24850.349775     67.762442      11.728942      7.680410
# std    14340.705287     38.315784       5.850779      4.199299
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12432.750000     35.000000       7.000000      4.100000
# 50%    24850.500000     69.000000      13.000000      7.100000
# 75%    37268.250000    100.000000      17.000000     11.100000
# max    49688.000000    134.000000      21.000000     25.000000

# %% [markdown]
# ## Check for mixed-data types in df_prods_checked

# %%
# check for mixed-data types

for col in df_prods_checked.columns.tolist():
    weird = (df_prods_checked[[col]].applymap(type) != df_prods_checked[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df_prods_checked[weird]) > 0:
        print (col)
        
# no columns printed means no mixed-data types in this data frame

# %% [markdown]
# As noted, already completed checks for missing values for df_prods_checked and duplicates from above exercise

# %%
# Export cleaned and checked data as data file, due to replacing outliers and with completed consistency checks

df_prods_checked.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'df_prods_checked.csv'))

# %% [markdown]
# # Consistency checks for df_ords dataframe

# %% [markdown]
# ## 2 Examine descriptive stats for df_ords

# %%
#descriptive states for df_ords

df_ords.describe()
# Out:
#            order_id       user_id  order_number  order_day_of_week  \
# count  3.421083e+06  3.421083e+06  3.421083e+06       3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01       2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01       2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00       0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00       1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01       3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01       5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02       6.000000e+00
#
#        order_hour_of_day  days_since_last_order
# count       3.421083e+06           3.214874e+06
# mean        1.345202e+01           1.111484e+01
# std         4.226088e+00           9.206737e+00
# min         0.000000e+00           0.000000e+00
# 25%         1.000000e+01           4.000000e+00
# 50%         1.300000e+01           7.000000e+00
# ...

# %% [markdown]
# All columns have matching number of rows except for days_since_last_order (see comment below)
#
# order_id, user_id, and order_number columns have 1 as the min value.
# order_day_of_week, order_hour_of_day, and days_since_last_order all have a 0 as min
# order_id has a large range, matching the idea of a unique identifier for each record
# max value for user_id does not match count of user_id, referencing customers having multiple orders
#
# the max value for order number is less than the counts of order_numbers, referencing orders that need to investigate
# max value of days_since_last_order of 30 does not seem accurate, want to investigate further
# The count of days_since_last_order does not match the counts of the other 5 columns, which means that there are significant missing values in the days_since_last_order. This could be from error or because it is a first time customer, will investigate further.

# %% [markdown]
# ## Explore df_ords to help with descriptive stats investigation

# %%
# View df_ords first 5 rows
df_ords.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_last_order
# 0                    NaN
# 1                   15.0
# 2                   21.0
# 3                   29.0
# 4                   28.0

# %%
# View df_ords last 5 rows
df_ords.tail()
# Out:
#          order_id  user_id  order_number  order_day_of_week  \
# 3421078   2266710   206209            10                  5
# 3421079   1854736   206209            11                  4
# 3421080    626363   206209            12                  1
# 3421081   2977660   206209            13                  1
# 3421082    272231   206209            14                  6
#
#          order_hour_of_day  days_since_last_order
# 3421078                 18                   29.0
# 3421079                 10                   30.0
# 3421080                 12                   18.0
# 3421081                 12                    7.0
# 3421082                 14                   30.0

# %%
# Check df_ords size
df_ords.shape
# Out:
# (3421083, 6)

# %% [markdown]
# ## 3 Check for mixed-data types for df_ords

# %%
# check for mixed-data types

for col in df_ords.columns.tolist():
    weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df_ords[weird]) > 0:
        print (col)

# %% [markdown]
# ## 4 Fix mixed-data types for df_ords

# %% [markdown]
# No columns printed means no mixed-data types detected for df_ords

# %% [markdown]
# ## 5 Check for missing values

# %% [markdown]
# As noted in descriptive stats observations, days_since_last_order has a different count than all other columns

# %%
# check for missing values in df_ords

df_ords.isnull().sum()

#consistent with exploratory investigation
# Out:
# order_id                      0
# user_id                       0
# order_number                  0
# order_day_of_week             0
# order_hour_of_day             0
# days_since_last_order    206209
# dtype: int64

# %%
# create subset of missing values within df_ords for days_since_last_order

df_ords_nan = df_ords[df_ords['days_since_last_order'].isnull() == True]

# %%
# View missing values 

df_ords_nan.head(50)
# Out:
#      order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0     2539329        1             1                  2                  8
# 11    2168274        2             1                  2                 11
# 26    1374495        3             1                  1                 14
# 39    3343014        4             1                  6                 11
# 45    2717275        5             1                  3                 12
# 50    2086598        6             1                  5                 18
# 54    2565571        7             1                  3                  9
# 75     600894        8             1                  6                  0
# 79     280530        9             1                  1                 17
# 83    1224907       10             1                  2                 14
# 89    2411567       11             1                  0                 11
# ...

# %%
df_ords_nan.tail(50)
# Out:
#          order_id  user_id  order_number  order_day_of_week  \
# 3420283   1684894   206160             1                  2
# 3420294   1013729   206161             1                  0
# 3420310   2614637   206162             1                  3
# 3420329    464023   206163             1                  6
# 3420335   1172115   206164             1                  3
# 3420341   2083902   206165             1                  3
# 3420369   3290085   206166             1                  4
# 3420389    351134   206167             1                  4
# 3420394   2450849   206168             1                  5
# 3420407   2668285   206169             1                  1
# 3420416   3202089   206170             1                  1
# 3420423    896963   206171             1                  2
# 3420430   2526805   206172             1                  6
# 3420437   1717723   206173             1                  1
# 3420441    559098   206174             1                  0
# ...

# %% [markdown]
# Observation: based on head and tail output, all of the NaN missing values for days_since_last_order have a order number of 1, meaning that they are first time customers.
#
# The max value in the 'user_id' column is 206209, which matches the number of missing values since these are each a new customer

# %% [markdown]
# ## 6 Address changes for missing values

# %% [markdown]
# Because all of the missing values correspond to a new customer, these are not inaccurate observations.
#
# Two options are to leave the 206209 values as NaN or to replace all NaN with 0.
#
# While leaving the values as NaN would still allow for descriptive statistics in python, but could lead to issues further down with creating visualizations.
#
# Replacing NaN with 0 would help with visualizations, and it would skew descriptive stats. Howeve it could also be used to show trends in new vs. established customer bases.
#
# Both NaN and 0 values could be used as indications of new customers.
#
# These missing values are important information and must be included in the data set.
#
# At this point, I chose to create a new data frame in which I replace NaN with 0, while also keeping df_ords df using NaN until I have more information about what stakeholders need in the analysis.

# %%
# Create new data frame where all NaN (new customer days_since_last_order) are listed as '0' rather than NaN

df_ords_new_cust_values = df_ords.fillna(0)

# %%
# check new data frame for replacement of null values

df_ords_new_cust_values.isnull().sum()

# accurate replacement
# Out:
# order_id                 0
# user_id                  0
# order_number             0
# order_day_of_week        0
# order_hour_of_day        0
# days_since_last_order    0
# dtype: int64

# %% [markdown]
# Note: based on next steps, may need to complete further checks on both df_ords_new_cust_values and df_ords prior to saving each data frame

# %% [markdown]
# ## 7 Run check for duplicate values

# %% [markdown]
# As noted, if duplicates are found, will need to address them in df_ords_new_cust_values as well as df_ords
# Can choose which df to utilize in analysis once stakeholders propose their needs and questions

# %%
# check for full duplicates in df_ords

df_dups = df_ords[df_ords.duplicated()]

# %%
# list of full duplicates

df_dups
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_day_of_week, order_hour_of_day, days_since_last_order]
# Index: []

# %% [markdown]
# ## 8 Address any duplicates found

# %% [markdown]
# Observation: no full duplicates found. Given meaning up data, any partial duplicates between columns are not worrisome since there are naturally duplicates across order_number, order_day_of_week, etc.
#
# No need for futher action regarding duplicates

# %% [markdown]
# ## 9 Export dataframes

# %% [markdown]
# Need to export df from products, orders, and also orders that replaced null values with 0

# %%
# Export cleaned and no duplicates products dataframe as new file

df_prods_clean_no_dups.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'df_prods_checked.csv'))

# %%
# Export cleaned orders dataframe with NaN (unchanged) missing values for new customers in 'days_since_last_order'

df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_checked.csv'), index = False)

# %%
# Export cleaned orders dataframe with changed missing values from NaN to '0' for new customers in'days_since_last_order'

df_ords_new_cust_values.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'df_ords_checked_new_cust_values.csv'), index = False)
