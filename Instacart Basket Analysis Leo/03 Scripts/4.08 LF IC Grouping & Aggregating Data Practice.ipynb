# %% [markdown]
# # Exercise 4.7 Data & Aggregating Variables

# %% [markdown]
# # Exercise Practice

# %% [markdown]
# ## Step 1 Preparing environment

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# Create path

path =  r"C:\Users\leobs\OneDrive\Data Program\Achievement 4_Instacart\Instacart Basket Analysis"

# %%
# Import dataframe, with new name as ords_prods_merge

ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merged.pkl'))

# %%
# Check import

ords_prods_merge.head()

# Successful import with updates from 4.7
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge        price_label  \
# ...

# %% [markdown]
# ## Create subset of data

# %%
# Subset for first 1000000

df = ords_prods_merge[:1000000]

# %%
# Check shape

df.shape
# Out:
# (1000000, 18)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge        price_label  \
# ...

# %% [markdown]
# ## Grouping data with pandas

# %%
# Groupby() test

df.groupby('product_name')

# As noted, will not show output

# %%
# Aggregate data with agg()

df.groupby('department_id').agg({'order_number': ['mean']})

# Finds average number of orders per department
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
# Another way with same results

df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
# Perform multipl aggregations for descriptive stats

df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})

# same min and max sometimes occur because clients pre-set min and max parameters
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# ## Aggregating with transform and creating loyalty flag using loc

# %%
# Group data, transform, and create a new column for customer order max values

ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Check output

ords_prods_merge.head(50)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# 5    3367565        1             6                  2                  7
# 6     550135        1             7                  1                  9
# 7    3108588        1             8                  1                 14
# 8    2295261        1             9                  1                 16
# 9    2550362        1            10                  4                  8
# 10   2968173       15            15                  1                  9
# 11   1870022       15            17                  2                 16
# ...

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# ..       ...      ...           ...                ...                ...
# 95   3226575      360             1                  5                 12
# 96   1469869      377             3                  5                 17
# 97   1927023      387             2                  4                 10
# 98    858092      420             4                  1                 19
# 99    119314      420             5                  3                 19
#
#     days_since_last_order  product_id  add_to_cart_order  reordered  \
# ...

# %%
# Command to not assign any options regarding the maximum number of rows to display, to help check aggregation

pd.options.display.max_rows = None

# Can delete output later

# %%
ords_prods_merge.head(100)

# Still unsure about how this changes the output, for example user id 15 does not have 27 rows even though their max is 27
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# 5    3367565        1             6                  2                  7
# 6     550135        1             7                  1                  9
# 7    3108588        1             8                  1                 14
# 8    2295261        1             9                  1                 16
# 9    2550362        1            10                  4                  8
# 10   2968173       15            15                  1                  9
# 11   1870022       15            17                  2                 16
# ...

# %%
# Create a flag to assign loyalty based on max order value

ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Check value counts

ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
# Check only select columns based on changes

ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# ...

# %%
df_user_fifteen = ords_prods_merge[ords_prods_merge['user_id']==15]

# %%
df_user_fifteen

# Checks out as accurate aggregation, order of rows had impact on seeing complete results prior
# Out:
#          order_id  user_id  order_number  order_day_of_week  \
# 10        2968173       15            15                  1
# 11        1870022       15            17                  2
# 12        1911383       15            18                  2
# 13        2715276       15            21                  1
# 14         487368       15            22                  1
# 51736     2514324       15             1                  5
# 51737     3135826       15             2                  6
# 51738      714991       15             4                  1
# 51739     3119091       15             8                  2
# 51740     2883598       15            12                  1
# 51741      113728       15            14                  1
# 51742     3097485       15            16                  1
# 51743     1870022       15            17                  2
# 51744     2345592       15            19                  5
# 51745     2994589       15            20                  1
# ...

# %% [markdown]
# ## Export updated dataframe

# %%
# Export ords_prods_merge with aggregations

ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))
